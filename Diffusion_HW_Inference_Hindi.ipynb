# %% [markdown]
# <a href="https://colab.research.google.com/github/keysun8/Diffusion_HW_Hindi/blob/main/Diffusion_HW_Inference_Hindi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/keysun8/Diffusion_HW_Hindi.git
# %cd Diffusion_HW_Hindi
# !pip install -r requirements.txt -q
# !pip install gdown huggingface_hub -q
# Out:
# Cloning into 'Diffusion_HW_Hindi'...
# remote: Enumerating objects: 522, done.
# remote: Counting objects: 100% (522/522), done.
# remote: Compressing objects: 100% (513/513), done.
# remote: Total 522 (delta 58), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (522/522), 3.33 MiB | 8.70 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/Diffusion_HW_Hindi
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.9/162.9 kB 6.0 MB/s eta 0:00:00

# %%
# !gdown --folder https://drive.google.com/drive/folders/1j7OpT5KYCkMf1oXEE9efufgB7lXAk17F -O ./vae
# Out:
# Retrieving folder contents
# Processing file 12P0ZLDxtYBoiFikG8KQO0wT_thJBWH-v config.json
# Processing file 1LWUv2fm_vR624vclbfrAcs6x6VMPMyYp diffusion_pytorch_model.safetensors
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=12P0ZLDxtYBoiFikG8KQO0wT_thJBWH-v
# To: /content/Diffusion_HW_Hindi/vae/config.json
# 100% 547/547 [00:00<00:00, 2.32MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1LWUv2fm_vR624vclbfrAcs6x6VMPMyYp
# From (redirected): https://drive.google.com/uc?id=1LWUv2fm_vR624vclbfrAcs6x6VMPMyYp&confirm=t&uuid=ef26d33f-689f-46ca-8cbd-ddaee0845429
# To: /content/Diffusion_HW_Hindi/vae/diffusion_pytorch_model.safetensors
# 100% 335M/335M [00:06<00:00, 55.6MB/s]
# Download completed

# %%
from huggingface_hub import list_repo_files, hf_hub_download

files = list_repo_files("keysun89/HW_Hindi_Model")
print(files)
# Out:
# ['.gitattributes', 'ckpt_epoch_434.pt']

# %%
ckpt_path = hf_hub_download(
    repo_id="keysun89/HW_Hindi_Model",
    filename="ckpt_epoch_434.pt",
)
print(ckpt_path)
# Out:
# ckpt_epoch_434.pt: reconstructing file:   0%|          |  0.00B / 3.19GB
# ckpt_epoch_434.pt: downloading bytes:           |  0.00B
# /root/.cache/huggingface/hub/models--keysun89--HW_Hindi_Model/snapshots/3f30194c578204f666f9323a117770160f3a309b/ckpt_epoch_434.pt

# %%
# !python inference.py \
    --ckpt  "/root/.cache/huggingface/hub/models--keysun89--HW_Hindi_Model/snapshots/3f30194c578204f666f9323a117770160f3a309b/ckpt_epoch_434.pt"\
    --style_folder /content/Diffusion_HW_Hindi/Hindi_HW_Imgs/Train_Imgs/11_train \
    --font_path /content/Diffusion_HW_Hindi/NotoSansDevanagari-Regular.ttf \
    --vae_path ./vae \
    --out_dir ./inference_out \
    --text "अटेंशन इज ऑल यू नीड"
# Out:
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Hello start !!
# [TEXT PROVIDED] 'अटेंशन इज ऑल यू नीड' (Native Devanagari detected)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-7ebf99e0.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-7ebf99e0.pth
# 100% 13.6M/13.6M [00:00<00:00, 126MB/s]
# [LOADED] checkpoint from epoch 434
# [STYLE IMAGE] /content/Diffusion_HW_Hindi/Hindi_HW_Imgs/Train_Imgs/11_train/4.jpg
# Random number R generated: 972
# [SAVED] ./inference_out/output_img_972.png
